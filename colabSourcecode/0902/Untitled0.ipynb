# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

sent1 = "the quick brown fox jumps over the lazy brown dog"
sent2 = "mr brown jumps over the lazy fox"

corpus = [sent1, sent2]
vectorizer = TfidfVectorizer(input='content')

X = vectorizer.fit_transform(corpus)
print(X.todense())
# Out:
# [[0.50077266 0.35190925 0.25038633 0.25038633 0.25038633 0.
#   0.25038633 0.35190925 0.50077266]
#  [0.35409974 0.         0.35409974 0.35409974 0.35409974 0.49767483
#   0.35409974 0.         0.35409974]]

# %%
vectorizer.vocabulary_
# Out:
# {'the': 8,
#  'quick': 7,
#  'brown': 0,
#  'fox': 2,
#  'jumps': 3,
#  'over': 6,
#  'lazy': 4,
#  'dog': 1,
#  'mr': 5}
