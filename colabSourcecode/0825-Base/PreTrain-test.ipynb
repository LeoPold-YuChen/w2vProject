# %%
from gensim.models import Word2Vec
w2v_model = Word2Vec(vector_size=300, sg=1, min_count=1)
w2v_model.build_vocab(more_sentences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-18712213a4a2> in <cell line: 3>()
#       1 from gensim.models import Word2Vec
#       2 w2v_model = Word2Vec(vector_size=300, sg=1, min_count=1)
# ----> 3 w2v_model.build_vocab(more_sentences)
#
# NameError: name 'more_sentences' is not defined
